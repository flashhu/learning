# %% [markdown]
# **复习：**在前面我们已经学习了Pandas基础，知道利用Pandas读取csv数据的增删查改，今天我们要学习的就是**探索性数据分析**，主要介绍如何利用Pandas进行排序、算术计算以及计算描述函数describe()的使用。

# %% [markdown]
# # 1 第一章：探索性数据分析

# %% [markdown]
# #### 开始之前，导入numpy、pandas包和数据

# %%
#加载所需的库
import numpy as np
import pandas as pd

# %%
# 注意设置编码！
df = pd.read_csv('train_chinese.csv', encoding='gb2312')
df.head()
# Out:
#    乘客ID  是否幸存  仓位等级                                                 姓名  \
# 0     1     0     3                            Braund, Mr. Owen Harris
# 1     2     1     1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2     3     1     3                             Heikkinen, Miss. Laina
# 3     4     1     1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4     5     0     3                           Allen, Mr. William Henry
#
#        性别    年龄  兄弟姐妹个数  父母子女个数              船票信息       票价    客舱 登船港口
# 0    male  22.0       1       0         A/5 21171   7.2500   NaN    S
# 1  female  38.0       1       0          PC 17599  71.2833   C85    C
# 2  female  26.0       0       0  STON/O2. 3101282   7.9250   NaN    S
# 3  female  35.0       1       0            113803  53.1000  C123    S
# 4    male  35.0       0       0            373450   8.0500   NaN    S

# %% [markdown]
# ### 1.6 了解你的数据吗？
# 教材《Python for Data Analysis》第五章

# %% [markdown]
# #### 1.6.1 任务一：利用Pandas对示例数据进行排序，要求升序

# %%
# 具体请看《利用Python进行数据分析》第五章 排序和排名 部分

#自己构建一个都为数字的DataFrame数据

df = pd.DataFrame(np.arange(8).reshape((2, 4)), index=[2, 1], columns=['d', 'a', 'b', 'c'])
df.head()
# Out:
#    d  a  b  c
# 2  0  1  2  3
# 1  4  5  6  7

# %% [markdown]
# 【代码解析】
#
# pd.DataFrame() ：创建一个DataFrame对象
#
# np.arange(8).reshape((2, 4)) : 生成一个二维数组（2*4）,第一列：0，1，2，3 第二列：4，5，6，7
#
# index=['2, 1] ：DataFrame 对象的索引列
#
# columns=['d', 'a', 'b', 'c'] ：DataFrame 对象的索引行

# %% [markdown]
# 【问题】：大多数时候我们都是想根据列的值来排序,所以将你构建的DataFrame中的数据根据某一列，升序排列

# %%
# 设置ascending 控制升/降序 默认为True, 升序
df.sort_values(by='a', ascending=False).head()
# Out:
#    d  a  b  c
# 1  4  5  6  7
# 2  0  1  2  3

# %% [markdown]
# 【思考】通过书本你能说出Pandas对DataFrame数据的其他排序方式吗？

# %% [markdown]
# 【总结】下面将不同的排序方式做一个总结

# %% [markdown]
# 1.让行索引升序排序

# %%
# 默认升序(ascending)，行索引（axis）
df.sort_index()
# Out:
#    d  a  b  c
# 1  4  5  6  7
# 2  0  1  2  3

# %% [markdown]
# 2.让列索引升序排序

# %%
df.sort_index(axis=1)
# Out:
#    a  b  c  d
# 2  1  2  3  0
# 1  5  6  7  4

# %% [markdown]
# 3.让列索引降序排序

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#    d  c  b  a
# 2  0  3  2  1
# 1  4  7  6  5

# %% [markdown]
# 4.让任选两列数据同时降序排序

# %%
df.sort_values(by=['a', 'b'], ascending=False)
# Out:
#    d  a  b  c
# 1  4  5  6  7
# 2  0  1  2  3

# %% [markdown]
# #### 1.6.2 任务二：对泰坦尼克号数据（trian.csv）按票价和年龄两列进行综合排序（降序排列），从这个数据中你可以分析出什么？

# %%
'''
在开始我们已经导入了train_chinese.csv数据，而且前面我们也学习了导入数据过程，根据上面学习，我们直接对目标列进行排序即可
head(20) : 读取前20条数据

'''

# %%
# 存活率 14/20 
df.sort_values(by=['票价', '年龄'], ascending=False).head(20)
# Out:
#      乘客ID  是否幸存  仓位等级                                                 姓名  \
# 679   680     1     1                 Cardeza, Mr. Thomas Drake Martinez
# 258   259     1     1                                   Ward, Miss. Anna
# 737   738     1     1                             Lesurer, Mr. Gustave J
# 438   439     0     1                                  Fortune, Mr. Mark
# 341   342     1     1                     Fortune, Miss. Alice Elizabeth
# 88     89     1     1                         Fortune, Miss. Mabel Helen
# 27     28     0     1                     Fortune, Mr. Charles Alexander
# 742   743     1     1              Ryerson, Miss. Susan Parker "Suzette"
# 311   312     1     1                         Ryerson, Miss. Emily Borie
# 299   300     1     1    Baxter, Mrs. James (Helene DeLaudeniere Chaput)
# 118   119     0     1                           Baxter, Mr. Quigg Edmond
# 380   381     1     1                              Bidois, Miss. Rosalie
# 716   717     1     1                      Endres, Miss. Caroline Louise
# 700   701     1     1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 557   558     0     1                                Robbins, Mr. Victor
# 527   528     0     1                                 Farthing, Mr. John
# 377   378     0     1                          Widener, Mr. Harry Elkins
# 779   780     1     1  Robert, Mrs. Edward Scott (Elisabeth Walton Mc...
# 730   731     1     1                      Allen, Miss. Elisabeth Walton
# 689   690     1     1                  Madill, Miss. Georgette Alexandra
#
#          性别    年龄  兄弟姐 妹个数  父母子女个数      船票信息        票价               客舱 登船港口
# 679    male  36.0        0       1  PC 17755  512.3292      B51 B53 B55    C
# 258  female  35.0        0       0  PC 17755  512.3292              NaN    C
# 737    male  35.0        0       0  PC 17755  512.3292             B101    C
# 438    male  64.0        1       4     19950  263.0000      C23 C25 C27    S
# 341  female  24.0        3       2     19950  263.0000      C23 C25 C27    S
# 88   female  23.0        3       2     19950  263.0000      C23 C25 C27    S
# 27     male  19.0        3       2     19950  263.0000      C23 C25 C27    S
# 742  female  21.0        2       2  PC 17608  262.3750  B57 B59 B63 B66    C
# 311  female  18.0        2       2  PC 17608  262.3750  B57 B59 B63 B66    C
# 299  female  50.0        0       1  PC 17558  247.5208          B58 B60    C
# 118    male  24.0        0       1  PC 17558  247.5208          B58 B60    C
# 380  female  42.0        0       0  PC 17757  227.5250              NaN    C
# 716  female  38.0        0       0  PC 17757  227.5250              C45    C
# 700  female  18.0        1       0  PC 17757  227.5250          C62 C64    C
# 557    male   NaN        0       0  PC 17757  227.5250              NaN    C
# 527    male   NaN        0       0  PC 17483  221.7792              C95    S
# 377    male  27.0        0       2    113503  211.5000              C82    C
# 779  female  43.0        0       1     24160  211.3375               B3    S
# 730  female  29.0        0       0     24160  211.3375               B5    S
# 689  female  15.0        0       1     24160  211.3375               B5    S

# %% [markdown]
# 【思考】排序后，如果我们仅仅关注年龄和票价两列。根据常识我知道发现票价越高的应该客舱越好，所以我们会明显看出，票价前20的乘客中存活的有14人，这是相当高的一个比例，那么我们后面是不是可以进一步分析一下票价和存活之间的关系，年龄和存活之间的关系呢？当你开始发现数据之间的关系了，数据分析就开始了。
#
# 当然，这只是我的想法，你还可以有更多想法，欢迎写在你的学习笔记中。

# %% [markdown]
# **多做几个数据的排序**

# %%
# 存活率 1/20
# 票价↑ 客舱↑ 存活率↑；票价↓ 客舱↓ 存活率↓
df.sort_values(by=['票价']).head(20)
# Out:
#      乘客ID  是否幸存  仓位等级                                姓名    性别    年龄  兄弟姐 妹个数  \
# 271   272     1     3      Tornquist, Mr. William Henry  male  25.0        0
# 597   598     0     3               Johnson, Mr. Alfred  male  49.0        0
# 302   303     0     3   Johnson, Mr. William Cahoone Jr  male  19.0        0
# 633   634     0     1     Parr, Mr. William Henry Marsh  male   NaN        0
# 277   278     0     2       Parkes, Mr. Francis "Frank"  male   NaN        0
# 413   414     0     2    Cunningham, Mr. Alfred Fleming  male   NaN        0
# 674   675     0     2        Watson, Mr. Ennis Hastings  male   NaN        0
# 263   264     0     1             Harrison, Mr. William  male  40.0        0
# 466   467     0     2             Campbell, Mr. William  male   NaN        0
# 732   733     0     2              Knight, Mr. Robert J  male   NaN        0
# 179   180     0     3               Leonard, Mr. Lionel  male  36.0        0
# 806   807     0     1            Andrews, Mr. Thomas Jr  male  39.0        0
# 481   482     0     2  Frost, Mr. Anthony Wood "Archie"  male   NaN        0
# 822   823     0     1   Reuchlin, Jonkheer. John George  male  38.0        0
# 815   816     0     1                  Fry, Mr. Richard  male   NaN        0
# 378   379     0     3               Betros, Mr. Tannous  male  20.0        0
# 872   873     0     1          Carlsson, Mr. Frans Olof  male  33.0        0
# 326   327     0     3         Nysveen, Mr. Johan Hansen  male  61.0        0
# 843   844     0     3        Lemberopolous, Mr. Peter L  male  34.5        0
# 818   819     0     3  Holm, Mr. John Fredrik Alexander  male  43.0        0
#
#      父母子女个数    船票信息      票价           客舱 登船港口
# 271       0    LINE  0.0000          NaN    S
# 597       0    LINE  0.0000          NaN    S
# 302       0    LINE  0.0000          NaN    S
# 633       0  112052  0.0000          NaN    S
# 277       0  239853  0.0000          NaN    S
# 413       0  239853  0.0000          NaN    S
# 674       0  239856  0.0000          NaN    S
# 263       0  112059  0.0000          B94    S
# 466       0  239853  0.0000          NaN    S
# 732       0  239855  0.0000          NaN    S
# 179       0    LINE  0.0000          NaN    S
# 806       0  112050  0.0000          A36    S
# 481       0  239854  0.0000          NaN    S
# 822       0   19972  0.0000          NaN    S
# 815       0  112058  0.0000         B102    S
# 378       0    2648  4.0125          NaN    C
# 872       0     695  5.0000  B51 B53 B55    S
# 326       0  345364  6.2375          NaN    S
# 843       0    2683  6.4375          NaN    C
# 818       0  C 7075  6.4500          NaN    S

# %%
# 存活率 5/20
df.sort_values(by=['年龄'], ascending=False).head(20)
# Out:
#      乘客ID  是否幸存  仓位等级                                         姓名      性别  \
# 630   631     1     1       Barkworth, Mr. Algernon Henry Wilson    male
# 851   852     0     3                        Svensson, Mr. Johan    male
# 493   494     0     1                    Artagaveytia, Mr. Ramon    male
# 96     97     0     1                  Goldschmidt, Mr. George B    male
# 116   117     0     3                       Connors, Mr. Patrick    male
# 672   673     0     2                Mitchell, Mr. Henry Michael    male
# 745   746     0     1               Crosby, Capt. Edward Gifford    male
# 33     34     0     2                      Wheadon, Mr. Edward H    male
# 54     55     0     1             Ostby, Mr. Engelhart Cornelius    male
# 280   281     0     3                           Duane, Mr. Frank    male
# 456   457     0     1                  Millet, Mr. Francis Davis    male
# 438   439     0     1                          Fortune, Mr. Mark    male
# 545   546     0     1               Nicholson, Mr. Arthur Ernest    male
# 275   276     1     1          Andrews, Miss. Kornelia Theodosia  female
# 483   484     1     3                     Turkula, Mrs. (Hedwig)  female
# 570   571     1     2                         Harris, Mr. George    male
# 252   253     0     1                  Stead, Mr. William Thomas    male
# 829   830     1     1  Stone, Mrs. George Nelson (Martha Evelyn)  female
# 555   556     0     1                         Wright, Mr. George    male
# 625   626     0     1                      Sutton, Mr. Frederick    male
#
#        年龄  兄弟姐 妹个数  父母子女个数         船票信息        票价           客舱 登船港口
# 630  80.0        0       0        27042   30.0000          A23    S
# 851  74.0        0       0       347060    7.7750          NaN    S
# 493  71.0        0       0     PC 17609   49.5042          NaN    C
# 96   71.0        0       0     PC 17754   34.6542           A5    C
# 116  70.5        0       0       370369    7.7500          NaN    Q
# 672  70.0        0       0   C.A. 24580   10.5000          NaN    S
# 745  70.0        1       1    WE/P 5735   71.0000          B22    S
# 33   66.0        0       0   C.A. 24579   10.5000          NaN    S
# 54   65.0        0       1       113509   61.9792          B30    C
# 280  65.0        0       0       336439    7.7500          NaN    Q
# 456  65.0        0       0        13509   26.5500          E38    S
# 438  64.0        1       4        19950  263.0000  C23 C25 C27    S
# 545  64.0        0       0          693   26.0000          NaN    S
# 275  63.0        1       0        13502   77.9583           D7    S
# 483  63.0        0       0         4134    9.5875          NaN    S
# 570  62.0        0       0  S.W./PP 752   10.5000          NaN    S
# 252  62.0        0       0       113514   26.5500          C87    S
# 829  62.0        0       0       113572   80.0000          B28  NaN
# 555  62.0        0       0       113807   26.5500          NaN    S
# 625  61.0        0       0        36963   32.3208          D50    S

# %%
# 存活率 13/20
# 年龄↓ 身体素质↑ 存活率↑；年龄↑ 身体素质↓ 存活率↓
df.sort_values(by=['年龄']).head(20)
# Out:
#      乘客ID  是否幸存  仓位等级                               姓名      性别    年龄  兄弟姐 妹个数  \
# 803   804     1     3  Thomas, Master. Assad Alexander    male  0.42        0
# 755   756     1     2        Hamalainen, Master. Viljo    male  0.67        1
# 644   645     1     3           Baclini, Miss. Eugenie  female  0.75        2
# 469   470     1     3    Baclini, Miss. Helene Barbara  female  0.75        2
# 78     79     1     2    Caldwell, Master. Alden Gates    male  0.83        0
# 831   832     1     2  Richards, Master. George Sibley    male  0.83        1
# 305   306     1     1   Allison, Master. Hudson Trevor    male  0.92        1
# 827   828     1     2            Mallet, Master. Andre    male  1.00        0
# 381   382     1     3      Nakid, Miss. Maria ("Mary")  female  1.00        0
# 164   165     0     3     Panula, Master. Eino Viljami    male  1.00        4
# 183   184     1     2        Becker, Master. Richard F    male  1.00        2
# 386   387     0     3  Goodwin, Master. Sidney Leonard    male  1.00        5
# 172   173     1     3     Johnson, Miss. Eleanor Ileen  female  1.00        1
# 788   789     1     3       Dean, Master. Bertram Vere    male  1.00        1
# 642   643     0     3    Skoog, Miss. Margit Elizabeth  female  2.00        3
# 7       8     0     3   Palsson, Master. Gosta Leonard    male  2.00        3
# 530   531     1     2         Quick, Miss. Phyllis May  female  2.00        1
# 297   298     0     1     Allison, Miss. Helen Loraine  female  2.00        1
# 824   825     0     3     Panula, Master. Urho Abraham    male  2.00        4
# 205   206     0     3       Strom, Miss. Telma Matilda  female  2.00        0
#
#      父母子女个数             船票信息        票价       客舱 登船港口
# 803       1             2625    8.5167      NaN    C
# 755       1           250649   14.5000      NaN    S
# 644       1             2666   19.2583      NaN    C
# 469       1             2666   19.2583      NaN    C
# 78        2           248738   29.0000      NaN    S
# 831       1            29106   18.7500      NaN    S
# 305       2           113781  151.5500  C22 C26    S
# 827       2  S.C./PARIS 2079   37.0042      NaN    C
# 381       2             2653   15.7417      NaN    C
# 164       1          3101295   39.6875      NaN    S
# 183       1           230136   39.0000       F4    S
# 386       2          CA 2144   46.9000      NaN    S
# 172       1           347742   11.1333      NaN    S
# 788       2        C.A. 2315   20.5750      NaN    S
# 642       2           347088   27.9000      NaN    S
# 7         1           349909   21.0750      NaN    S
# 530       1            26360   26.0000      NaN    S
# 297       2           113781  151.5500  C22 C26    S
# 824       1          3101295   39.6875      NaN    S
# 205       1           347054   10.4625       G6    S

# %% [markdown]
# #### 1.6.3 任务三：利用Pandas进行算术计算，计算两个DataFrame数据相加结果

# %%
# 具体请看《利用Python进行数据分析》第五章 算术运算与数据对齐 部分

#自己构建两个都为数字的DataFrame数据

df_1 = pd.DataFrame(np.arange(8).reshape((2, 4)), index=[2, 1], columns=['d', 'a', 'b', 'c'])
df_2 = pd.DataFrame(np.arange(8, 16).reshape((2, 4)), index=[2, 1], columns=['d', 'a', 'b', 'c'])
df_1
# Out:
#    d  a  b  c
# 2  0  1  2  3
# 1  4  5  6  7

# %%
df_2
# Out:
#     d   a   b   c
# 2   8   9  10  11
# 1  12  13  14  15

# %% [markdown]
# 将frame_a和frame_b进行相加

# %%
df_1 + df_2
# Out:
#     d   a   b   c
# 2   8  10  12  14
# 1  16  18  20  22

# %% [markdown]
# 【提醒】两个DataFrame相加后，会返回一个新的DataFrame，对应的行和列的值会相加，没有对应的会变成空值NaN。<br>
# 当然，DataFrame还有很多算术运算，如减法，除法等，有兴趣的同学可以看《利用Python进行数据分析》第五章 算术运算与数据对齐 部分，多在网络上查找相关学习资料。

# %% [markdown]
# #### 1.6.4 任务四：通过泰坦尼克号数据如何计算出在船上最大的家族有多少人？

# %%
'''
还是用之前导入的chinese_train.csv如果我们想看看在船上，最大的家族有多少人（‘兄弟姐妹个数’+‘父母子女个数’），我们该怎么做呢？
'''
df['家族人数'] = df['兄弟姐妹个数'] + df['父母子女个数']
max(df['家族人数'])
# Out:
# 10

# %%
df.sort_values(by='家族人数', ascending=False).head(10)
# Out:
#      乘客ID  是否幸存  仓位等级                                       姓名      性别    年龄  \
# 180   181     0     3             Sage, Miss. Constance Gladys  female   NaN
# 846   847     0     3                 Sage, Mr. Douglas Bullen    male   NaN
# 792   793     0     3                  Sage, Miss. Stella Anna  female   NaN
# 201   202     0     3                      Sage, Mr. Frederick    male   NaN
# 159   160     0     3               Sage, Master. Thomas Henry    male   NaN
# 863   864     0     3        Sage, Miss. Dorothy Edith "Dolly"  female   NaN
# 324   325     0     3                 Sage, Mr. George John Jr    male   NaN
# 386   387     0     3          Goodwin, Master. Sidney Leonard    male   1.0
# 59     60     0     3       Goodwin, Master. William Frederick    male  11.0
# 678   679     0     3  Goodwin, Mrs. Frederick (Augusta Tyler)  female  43.0
#
#      兄弟姐妹个数  父母子女个数      船票信息     票价   客舱 登船港口  家族人数
# 180       8       2  CA. 2343  69.55  NaN    S    10
# 846       8       2  CA. 2343  69.55  NaN    S    10
# 792       8       2  CA. 2343  69.55  NaN    S    10
# 201       8       2  CA. 2343  69.55  NaN    S    10
# 159       8       2  CA. 2343  69.55  NaN    S    10
# 863       8       2  CA. 2343  69.55  NaN    S    10
# 324       8       2  CA. 2343  69.55  NaN    S    10
# 386       5       2   CA 2144  46.90  NaN    S     7
# 59        5       2   CA 2144  46.90  NaN    S     7
# 678       1       6   CA 2144  46.90  NaN    S     7

# %% [markdown]
# 【提醒】我们只需找出”兄弟姐妹个数“和”父母子女个数“之和最大的数，当然你还可以想出很多方法和思考角度，欢迎你来说出你的看法。

# %% [markdown]
# #### 1.6.5 任务五：学会使用Pandas describe()函数查看数据基本统计信息

# %%
#(1) 关键知识点示例做一遍（简单数据）
# 具体请看《利用Python进行数据分析》第五章 汇总和计算描述统计 部分

#自己构建一个有数字有空值的DataFrame数据

df_3 = pd.DataFrame({'a':{'c': 1}, 'b':{'c': 3, 'd': 4}})
df_3
# Out:
#      a  b
# c  1.0  3
# d  NaN  4

# %% [markdown]
# 调用 describe 函数，观察frame2的数据基本信息

# %%
df_3.describe()
# Out:
#          a         b
# count  1.0  2.000000
# mean   1.0  3.500000
# std    NaN  0.707107
# min    1.0  3.000000
# 25%    1.0  3.250000
# 50%    1.0  3.500000
# 75%    1.0  3.750000
# max    1.0  4.000000

# %% [markdown]
# #### 1.6.6 任务六：分别看看泰坦尼克号数据集中 票价、父母子女 这列数据的基本统计数据，你能发现什么？

# %%
'''
看看泰坦尼克号数据集中 票价 这列数据的基本统计数据
'''

# %%
df[['票价', '父母子女个数', '兄弟姐妹个数', '家族人数']].describe()
# Out:
#                票价      父母子女个数      兄弟姐妹个数        家族人数
# count  891.000000  891.000000  891.000000  891.000000
# mean    32.204208    0.381594    0.523008    0.904602
# std     49.693429    0.806057    1.102743    1.613459
# min      0.000000    0.000000    0.000000    0.000000
# 25%      7.910400    0.000000    0.000000    0.000000
# 50%     14.454200    0.000000    0.000000    0.000000
# 75%     31.000000    0.000000    1.000000    1.000000
# max    512.329200    6.000000    8.000000   10.000000

# %% [markdown]
# 【思考】从上面数据我们可以看出，试试在下面写出你的看法。然后看看我们给出的答案。
#
# 当然，答案只是我的想法，你还可以有更多想法，欢迎写在你的学习笔记中。

# %% [markdown]
# * 票价的平均值低，不同档位票价差别大
# * 家族人数平均少，大部分为孤身

# %% [markdown]
# **多做几个组数据的统计，看看你能分析出什么？**

# %%
df[['年龄']].describe()
# Out:
#                年龄
# count  714.000000
# mean    29.699118
# std     14.526497
# min      0.420000
# 25%     20.125000
# 50%     28.000000
# 75%     38.000000
# max     80.000000

# %%
df[df['年龄'] < 18].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 113 entries, 7 to 875
# Data columns (total 13 columns):
# 乘客ID      113 non-null int64
# 是否幸存      113 non-null int64
# 仓位等级      113 non-null int64
# 姓名        113 non-null object
# 性别        113 non-null object
# 年龄        113 non-null float64
# 兄弟姐妹个数    113 non-null int64
# 父母子女个数    113 non-null int64
# 船票信息      113 non-null object
# 票价        113 non-null float64
# 客舱        19 non-null object
# 登船港口      113 non-null object
# 家族人数      113 non-null int64
# dtypes: float64(2), int64(6), object(5)
# memory usage: 12.4+ KB

# %% [markdown]
# * 75%年龄低于40，大部分为青壮年

# %% [markdown]
# 【思考】有更多想法，欢迎写在你的学习笔记中。

# %% [markdown]
# 【总结】本节中我们通过Pandas的一些内置函数对数据进行了初步统计查看，这个过程最重要的不是大家得掌握这些函数，而是看懂从这些函数出来的数据，构建自己的数据分析思维，这也是第一章最重要的点，希望大家学完第一章能对数据有个基本认识，了解自己在做什么，为什么这么做，后面的章节我们将开始对数据进行清洗，进一步分析。
